# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/Mistral/RA1/IL1.2/3-chain-of-thought.ipynb)

# %% [markdown]
# # 3. Chain-of-Thought (CoT) Prompting - Razonamiento Paso a Paso
#
# ## Objetivos de Aprendizaje
# - Comprender el concepto de Chain-of-Thought (CoT) prompting
# - Implementar CoT con y sin ejemplos
# - Aplicar CoT a problemas complejos y razonamiento lógico
# - Combinar CoT con otras técnicas de prompting
#
# ## ¿Qué es Chain-of-Thought?
#
# Chain-of-Thought (CoT) es una técnica que hace que el modelo "**piense en voz alta**" mostrando su proceso de razonamiento paso a paso antes de llegar a la respuesta final.
#
# ### Principio Básico:
# En lugar de saltar directamente a la respuesta, el modelo:
# 1. **Descompone** el problema en pasos
# 2. **Razona** cada paso explícitamente
# 3. **Construye** hacia la solución final
# 4. **Proporciona** la respuesta con justificación
#
# ### Ventajas:
# - **Mejor precisión**: Especialmente en problemas complejos
# - **Transparencia**: Puedes ver el razonamiento
# - **Debugging**: Identificar dónde falla el razonamiento
# - **Confianza**: Mayor seguridad en la respuesta
#
# ### Casos de Uso Ideales:
# - Problemas matemáticos
# - Razonamiento lógico
# - Análisis complejos
# - Toma de decisiones
# - Resolución de problemas multi-paso

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 26.9 MB/s eta 0:00:00

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.mistral.ai/v1")
    os.environ.setdefault("LLM_MODEL", "mistral-small-latest")
    os.environ.setdefault("LLM_MODEL_SMALL", "ministral-8b-latest")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
    temperature=0.1  # Baja temperatura para razonamiento más consistente
)

print("✓ Modelo configurado para Chain-of-Thought")
print("✓ Temperature baja para razonamiento consistente")
# Out:
# ✓ Modelo configurado para Chain-of-Thought
# ✓ Temperature baja para razonamiento consistente

# %% [markdown]
# ## Comparación: Sin CoT vs Con CoT
#
# Veamos la diferencia dramática que puede hacer CoT en problemas complejos.

# %%
# Comparación directa: razonamiento directo vs CoT
def comparar_sin_vs_con_cot():
    print("=== COMPARACIÓN: SIN CoT vs CON CoT ===")

    # Problema complejo que requiere múltiples pasos
    problema = """Una tienda tiene una promoción: 'Compra 2 productos y obtén 30% de descuento en el más barato'.
    Juan compra una camiseta de 45€, unos zapatos de 120€ y una chaqueta de 80€.
    ¿Cuánto paga en total?"""

    # Prompt sin CoT
    prompt_sin_cot = f"""Resuelve este problema:

{problema}

Respuesta:"""

    # Prompt con CoT
    prompt_con_cot = f"""Resuelve este problema paso a paso:

{problema}

Piensa paso a paso:
1. Primero identifica los productos y precios
2. Determina cómo se aplica la promoción
3. Calcula el descuento
4. Calcula el total final

Razonamiento:"""

    # Probar sin CoT
    print("\n1. SIN CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_sin = llm.invoke([HumanMessage(content=prompt_sin_cot)])
        print(response_sin.content)
    except Exception as e:
        print(f"Error: {e}")

    print("\n" + "="*60)

    # Probar con CoT
    print("\n2. CON CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_con = llm.invoke([HumanMessage(content=prompt_con_cot)])
        print(response_con.content)
    except Exception as e:
        print(f"Error: {e}")

    print("\n=== ANÁLISIS ===")
    print("• Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos")
    print("• Con CoT: Muestra razonamiento completo y reduce errores")
    print("• CoT especialmente útil para problemas multi-paso")

# Ejecutar comparación
comparar_sin_vs_con_cot()
# Out:
# === COMPARACIÓN: SIN CoT vs CON CoT ===
#
# 1. SIN CHAIN-OF-THOUGHT:
# ------------------------------
# Para resolver el problema, seguiremos los pasos de la promoción de la tienda:
#
# **Promoción:** "Compra 2 productos y obtén 30% de descuento en el más barato".
#
# **Productos comprados por Juan:**
# 1. Camiseta: 45€
# 2. Zapatos: 120€
# 3. Chaqueta: 80€
#
# **Paso 1:** Identificar los dos productos más caros para aplicar la promoción.
# - Los dos productos más caros son los zapatos (120€) y la chaqueta (80€).
#
# **Paso 2:** Aplicar el 30% de descuento al producto más barato de los dos seleccionados.
# - El más barato entre los zapatos y la chaqueta es la chaqueta (80€).
# - Descuento: 30% de 80€ = 0.30 × 80 = 24€.
# - Precio con descuento: 80€ - 24€ = 56€.
#
# **Paso 3:** Sumar el precio de los tres productos con el descuento aplicado.
# - Camiseta: 45€
# - Zapatos: 120€
# - Chaqueta con descuento: 56€
# - **Total:** 45€ + 120€ + 56€ = 221€.
#
# **Respuesta final:**
# Juan paga **221€** en total.
#
# ============================================================
#
# 2. CON CHAIN-OF-THOUGHT:
# ------------------------------
# Vamos a resolver el problema paso a paso:
#
# 1. **Identifica los productos y precios**:
#    - Camiseta: 45€
#    - Zapatos: 120€
#    - Chaqueta: 80€
#
# 2. **Determina cómo se aplica la promoción**:
#    La promoción dice: "Compra 2 productos y obtén 30% de descuento en el más barato".
#    - Juan compra 3 productos, pero la promoción solo se aplica a 2 productos.
#    - Para maximizar el beneficio, debemos elegir los dos productos más caros para aplicar el descuento en el más barato de esos dos.
#    - Los dos productos más caros son los zapatos (120€) y la chaqueta (80€).
#    - El más barato de estos dos es la chaqueta (80€).
#
# 3. **Calcula el descuento**:
#    - Descuento en la chaqueta: 30% de 80€ = 0.30 * 80 = 24€.
#    - Precio final de la chaqueta: 80€ - 24€ = 56€.
#
# 4. **Calcula el total final**:
#    - Camiseta: 45€
#    - Zapatos: 120€
#    - Chaqueta con descuento: 56€
#    - Total: 45€ + 120€ + 56€ = 221€.
#
# **Respuesta final**: Juan paga **221€** en total.
#
# === ANÁLISIS ===
# • Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos
# • Con CoT: Muestra razonamiento completo y reduce errores
# • CoT especialmente útil para problemas multi-paso

# %% [markdown]
# ## Zero-Shot Chain-of-Thought
#
# La forma más simple de CoT: simplemente pedirle al modelo que "piense paso a paso".

# %%
# Zero-shot CoT: solo agregar "piensa paso a paso"
def zero_shot_cot():
    print("=== ZERO-SHOT CHAIN-OF-THOUGHT ===")

    problemas = [
        "Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?",
        "Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?",
        "María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?"
    ]

    for i, problema in enumerate(problemas, 1):
        print(f"\n{i}. PROBLEMA:")
        print(f"{problema}")

        # Prompt zero-shot CoT
        prompt = f"{problema}\n\nPiensa paso a paso:"

        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print("\nSOLUCIÓN:")
            print(response.content)

            # Análisis básico del razonamiento
            pasos = response.content.count('\n')
            tiene_calculo = any(op in response.content for op in ['+', '-', '*', '/', '=', '%'])

            print(f"\nAnálisis: {pasos} líneas de razonamiento, {'con' if tiene_calculo else 'sin'} cálculos explícitos")

        except Exception as e:
            print(f"Error: {e}")

        print("-" * 80)

# Ejecutar zero-shot CoT
zero_shot_cot()
# Out:
# === ZERO-SHOT CHAIN-OF-THOUGHT ===
#
# 1. PROBLEMA:
# Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?
#
# SOLUCIÓN:
# Vamos a calcular el tiempo total del viaje paso a paso.
#
# 1. **Tiempo de viaje sin paradas:**
#
#    - **Distancia:** 240 km
#    - **Velocidad:** 80 km/h
#
#    \[
#    \text{Tiempo} = \frac{\text{Distancia}}{\text{Velocidad}} = \frac{240\,\text{km}}{80\,\text{km/h}} = 3\,\text{horas}
#    \]
#
# 2. **Tiempo de parada en la estación:**
#
#    - **Duración de la parada:** 15 minutos
#
#    Convertimos los minutos a horas para mantener la unidad:
#
#    \[
#    15\,\text{minutos} = \frac{15}{60}\,\text{horas} = 0.25\,\text{horas}
#    \]
#
# 3. **Tiempo total del viaje:**
#
#    \[
#    \text{Tiempo total} = \text{Tiempo de viaje} + \text{Tiempo de parada} = 3\,\text{horas} + 0.25\,\text{horas} = 3.25\,\text{horas}
#    \]
#
#    Convertimos 0.25 horas a minutos para mayor claridad:
#
#    \[
#    0.25\,\text{horas} \times 60\,\text{minutos/hora} = 15\,\text{minutos}
#    \]
#
#    Por lo tanto, el tiempo total es **3 horas y 15 minutos**.
#
# **Respuesta final:**
#
# \[
# \boxed{3\,\text{horas y }15\,\text{minutos}}
# \]
#
# Análisis: 39 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 2. PROBLEMA:
# Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?
#
# SOLUCIÓN:
# Vamos a resolver el problema paso a paso.
#
# 1. **Calcular el número de empleados en el departamento de desarrollo:**
#
#    La empresa tiene 150 empleados en total. El 40% trabaja en desarrollo.
#
#    \[
#    \text{Número de empleados en desarrollo} = 40\% \times 150 = 0.40 \times 150 = 60 \text{ empleados}
#    \]
#
# 2. **Calcular el costo anual del departamento de desarrollo:**
#
#    Cada empleado de desarrollo gana 50,000€ anuales.
#
#    \[
#    \text{Costo anual} = 60 \text{ empleados} \times 50,000€ = 3,000,000€
#    \]
#
# **Respuesta final:**
#
# \[
# \boxed{3,\!000,\!000}
# \]
#
# Análisis: 22 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 3. PROBLEMA:
# María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?
#
# SOLUCIÓN:
# Vamos a resolver el problema paso a paso.
#
# **1. Definir las variables:**
# - Sea \( A \) la edad actual de Ana.
# - Como María tiene el triple de edad que Ana, la edad actual de María es \( 3A \).
#
# **2. Plantear la ecuación para dentro de 5 años:**
# - En 5 años, Ana tendrá \( A + 5 \) años.
# - En 5 años, María tendrá \( 3A + 5 \) años.
# - Según el problema, en 5 años María tendrá el doble de edad que Ana. Por lo tanto:
#   \[
#   3A + 5 = 2(A + 5)
#   \]
#
# **3. Resolver la ecuación:**
# \[
# \begin{align*}
# 3A + 5 &= 2(A + 5) \\
# 3A + 5 &= 2A + 10 \\
# 3A - 2A &= 10 - 5 \\
# A &= 5
# \end{align*}
# \]
#
# **4. Calcular la edad de María:**
# \[
# 3A = 3 \times 5 = 15
# \]
#
# **5. Verificar la solución:**
# - Edad actual de Ana: 5 años.
# - Edad actual de María: 15 años.
# - En 5 años:
#   - Ana tendrá \( 5 + 5 = 10 \) años.
#   - María tendrá \( 15 + 5 = 20 \) años.
#   - Efectivamente, \( 20 = 2 \times 10 \), lo que cumple la condición del problema.
#
# **Respuesta final:**
# - Ana tiene **5 años**.
# - María tiene **15 años**.
#
# Análisis: 39 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Few-Shot Chain-of-Thought
#
# Combinamos CoT con ejemplos para mostrar el patrón de razonamiento deseado.

# %%
# Few-shot CoT: ejemplos con razonamiento paso a paso
def few_shot_cot():
    print("=== FEW-SHOT CHAIN-OF-THOUGHT ===")

    # Nuevo problema para resolver
    nuevo_problema = "Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?"

    # Prompt con ejemplos de razonamiento
    prompt_few_shot_cot = f"""Resuelve problemas matemáticos mostrando el razonamiento paso a paso:

Problema: Una pizza cuesta 12€ y cada ingrediente extra cuesta 1.50€. Si Pedro paga 18€, ¿cuántos ingredientes extra pidió?
Razonamiento:
1. Precio base de la pizza: 12€
2. Total pagado: 18€
3. Dinero gastado en extras: 18€ - 12€ = 6€
4. Costo por ingrediente extra: 1.50€
5. Número de ingredientes: 6€ ÷ 1.50€ = 4 ingredientes
Respuesta: Pedro pidió 4 ingredientes extra.

Problema: En una clase hay 24 estudiantes. Si se forman grupos de 6 estudiantes cada uno, ¿cuántos grupos se pueden formar? Si sobra algún estudiante, ¿cuántos?
Razonamiento:
1. Total de estudiantes: 24
2. Estudiantes por grupo: 6
3. División: 24 ÷ 6 = 4 grupos exactos
4. Verificación: 4 × 6 = 24 estudiantes
5. Resto: 24 - 24 = 0 estudiantes sobran
Respuesta: Se pueden formar 4 grupos completos y no sobra ningún estudiante.

Problema: {nuevo_problema}
Razonamiento:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_few_shot_cot)])
        print("PROBLEMA A RESOLVER:")
        print(nuevo_problema)
        print("\nSOLUCIÓN CON RAZONAMIENTO:")
        print(response.content)

        # Verificar si siguió el patrón
        razonamiento = response.content
        tiene_pasos_numerados = bool(re.search(r'\d+\.', razonamiento))
        tiene_calculos = any(op in razonamiento for op in ['=', '+', '-', '*', '/', '€'])
        tiene_respuesta_final = 'respuesta' in razonamiento.lower()

        print("\n=== ANÁLISIS DEL PATRÓN ===")
        print(f"✓ Pasos numerados: {'Sí' if tiene_pasos_numerados else 'No'}")
        print(f"✓ Cálculos explícitos: {'Sí' if tiene_calculos else 'No'}")
        print(f"✓ Respuesta final clara: {'Sí' if tiene_respuesta_final else 'No'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar few-shot CoT
import re
few_shot_cot()
# Out:
# === FEW-SHOT CHAIN-OF-THOUGHT ===
# PROBLEMA A RESOLVER:
# Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# SOLUCIÓN CON RAZONAMIENTO:
# **Problema:** Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# **Razonamiento:**
#
# 1. **Costo de la primera hora:** 3€ (incluye la primera hora).
# 2. **Dinero restante después de la primera hora:** 15€ - 3€ = 12€.
# 3. **Costo por hora adicional:** 2€.
# 4. **Número de horas adicionales:** 12€ ÷ 2€ = 6 horas.
# 5. **Total de horas estacionado:** 1 hora (base) + 6 horas (adicionales) = **7 horas**.
#
# **Respuesta:** Estuvo estacionado **7 horas**.
#
# === ANÁLISIS DEL PATRÓN ===
# ✓ Pasos numerados: Sí
# ✓ Cálculos explícitos: Sí
# ✓ Respuesta final clara: Sí

# %% [markdown]
# ## CoT para Razonamiento Lógico
#
# Chain-of-Thought es especialmente poderoso para problemas de lógica y deducción.

# %%
# CoT para problemas de lógica
def cot_razonamiento_logico():
    print("=== CoT PARA RAZONAMIENTO LÓGICO ===")

    # Problema de lógica clásico
    problema_logica = """En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
    - Ana no está al lado de Bruno
    - Carlos está exactamente frente a Diana
    - Elena está al lado derecho de Ana
    - Bruno está al lado de Carlos

¿Cuál es la disposición completa alrededor de la mesa?"""

    prompt_logica = f"""Resuelve este problema de lógica paso a paso:

{problema_logica}

Razona sistemáticamente:
1. Identifica las restricciones
2. Establece relaciones conocidas
3. Deduce posiciones paso a paso
4. Verifica que se cumplan todas las condiciones

Proceso de deducción:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_logica)])
        print("PROBLEMA DE LÓGICA:")
        print(problema_logica)
        print("\nPROCESO DE RAZONAMIENTO:")
        print(response.content)

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar razonamiento lógico
cot_razonamiento_logico()
# Out:
# === CoT PARA RAZONAMIENTO LÓGICO ===
# PROBLEMA DE LÓGICA:
# En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
#     - Ana no está al lado de Bruno
#     - Carlos está exactamente frente a Diana
#     - Elena está al lado derecho de Ana
#     - Bruno está al lado de Carlos
#
# ¿Cuál es la disposición completa alrededor de la mesa?
#
# PROCESO DE RAZONAMIENTO:
# Vamos a resolver el problema paso a paso siguiendo el razonamiento sistemático propuesto.
#
# ---
#
# ### **1. Identifica las restricciones**
# Tenemos 5 personas sentadas en una mesa redonda: **Ana (A), Bruno (B), Carlos (C), Diana (D) y Elena (E)**.
# Las restricciones son:
# 1. **Ana no está al lado de Bruno** (A no adyacente a B).
# 2. **Carlos está exactamente frente a Diana** (C frente a D).
# 3. **Elena está al lado derecho de Ana** (E a la derecha de A).
# 4. **Bruno está al lado de Carlos** (B adyacente a C).
#
# ---
#
# ### **2. Establece relaciones conocidas**
# - **Restricción 2 (C frente a D):**
#   En una mesa redonda con 5 personas, "frente" significa que hay **2 personas entre ellos** (ya que 5 es impar, no hay un frente exacto como en mesas pares, pero podemos interpretar que están separados por 2 asientos en cualquier dirección).
#   Por ejemplo, si C está en la posición 1, D podría estar en la posición 4 (1 + 3 = 4, ya que 5/2 = 2.5, redondeamos a 3).
#
# - **Restricción 3 (E a la derecha de A):**
#   Si A está en una posición, E debe estar en la siguiente posición en sentido horario (derecha).
#
# - **Restricción 4 (B adyacente a C):**
#   B debe estar inmediatamente a la izquierda o derecha de C.
#
# - **Restricción 1 (A no adyacente a B):**
#   A y B no pueden estar juntos.
#
# ---
#
# ### **3. Deduce posiciones paso a paso**
# Vamos a asignar posiciones numéricas a la mesa (1 a 5 en sentido horario) y probar combinaciones.
#
# #### **Paso 1: Colocar a C y D (frente)**
# Supongamos que C está en la posición **1**. Entonces D debe estar en la posición **4** (1 + 3 = 4).
# Otras opciones para D serían 1 - 3 = -2 → 3 (en módulo 5), pero probaremos primero con D en 4.
#
# **Posición actual:**
# 1: C
# 4: D
#
# #### **Paso 2: Colocar a B (adyacente a C)**
# B debe estar al lado de C (posición 1), así que B puede estar en **2** o **5**.
#
# **Opción A:** B en 2.
# **Opción B:** B en 5.
#
# Probamos primero la **Opción A (B en 2)**.
#
# **Posición actual:**
# 1: C
# 2: B
# 4: D
#
# #### **Paso 3: Colocar a A y E (E a la derecha de A)**
# E debe estar a la derecha de A (siguiente posición en sentido horario).
# Posibles posiciones para A: 3 o 5 (ya que 1, 2 y 4 están ocupadas).
#
# - Si A está en **3**, entonces E debe estar en **4**. Pero 4 ya está ocupado por D → **Inválido**.
# - Si A está en **5**, entonces E debe estar en **1**. Pero 1 ya está ocupado por C → **Inválido**.
#
# **Conclusión:** La Opción A (B en 2) no funciona. Probamos la **Opción B (B en 5)**.
#
# **Posición actual:**
# 1: C
# 4: D
# 5: B
#
# #### **Paso 4: Colocar a A y E (E a la derecha de A)**
# Posibles posiciones para A: 2 o 3.
#
# - Si A está en **2**, entonces E debe estar en **3**.
#   Verificamos restricciones:
#   - A (2) no adyacente a B (5): Las posiciones adyacentes a 2 son 1 y 3. B está en 5 → **Cumple**.
#   - B (5) adyacente a C (1): Las posiciones adyacentes a 5 son 4 y 1. C está en 1 → **Cumple**.
#   - C (1) frente a D (4): Separados por 2 personas (posiciones 2 y 3) → **Cumple**.
#   - E (3) a la derecha de A (2) → **Cumple**.
#
# **Disposición actual:**
# 1: C
# 2: A
# 3: E
# 4: D
# 5: B
#
# #### **Paso 5: Verificar todas las restricciones**
# 1. **Ana no está al lado de Bruno:**
#    A (2) y B (5) no son adyacentes (adyacentes de A: 1 y 3; adyacentes de B: 4 y 1) → **Cumple**.
# 2. **Carlos frente a Diana:**
#    C (1) y D (4) están separados por 2 personas (A y E) → **Cumple**.
# 3. **Elena al lado derecho de Ana:**
#    A (2) → E (3) (siguiente en sentido horario) → **Cumple**.
# 4. **Bruno al lado de Carlos:**
#    B (5) y C (1) son adyacentes → **Cumple**.
#
# **Todas las restricciones se cumplen.**
#
# ---
#
# ### **4. Solución final**
# La disposición alrededor de la mesa (en sentido horario) es:
#
# 1. **Carlos**
# 2. **Ana**
# 3. **Elena**
# 4. **Diana**
# 5. **Bruno**
#
# **Representación gráfica:**
# ```
#         Carlos
# Bruno               Ana
#     Elena   Diana
# ```
# (Nota: En una mesa redonda, las posiciones son cíclicas, así que el orden es 1 → 2 → 3 → 4 → 5 → 1.)
#
# ---
#
# ### **Verificación alternativa**
# Para asegurarnos, probamos otra posición inicial para C y D:
# - Si C está en 2, D debe estar en 5 (2 + 3 = 5).
#   - B debe estar al lado de C (2), así que B en 1 o 3.
#     - Si B en 1:
#       - A y E: posibles A en 3 o 4.
#         - A en 3 → E en 4.
#           - Verificar: A (3) no adyacente a B (1) → adyacentes de A: 2 y 4; adyacentes de B: 5 y 2 → **Cumple**.
#           - B (1) adyacente a C (2) → **Cumple**.
#           - C (2) frente a D (5) → separados por 2 personas (A y E) → **Cumple**.
#           - E (4) a la derecha de A (3) → **Cumple**.
#       - Disposición: 1:B, 2:C, 3:A, 4:E, 5:D.
#       - Pero en este caso, **Ana (3) está adyacente a Bruno (1)** (adyacentes de A: 2 y 4; adyacentes de B: 5 y 2) → **No cumple la restricción 1**.
#     - Si B en 3:
#       - A y E: posibles A en 1 o 4.
#         - A en 1 → E en 2 (pero 2 es C) → **Inválido**.
#         - A en 4 → E en 5 (pero 5 es D) → **Inválido**.
#   - Conclusión: Esta disposición no funciona.
#
# Por lo tanto, la única solución válida es la primera que encontramos.
#
# ---
#
# ### **Respuesta final**
# La disposición correcta alrededor de la mesa (en orden horario) es:
#
# **Carlos, Ana, Elena, Diana, Bruno.**

# %%
# CoT para análisis de casos complejos
def cot_analisis_complejo():
    print("=== CoT PARA ANÁLISIS COMPLEJO ===")

    # Caso de negocio complejo
    caso_negocio = """Una startup de software tiene las siguientes métricas:
    - 10,000 usuarios activos mensuales
    - Tasa de conversión a premium: 5%
    - Precio premium: 29€/mes
    - Costo de adquisición por usuario: 15€
    - Retención mensual: 85%
    - Costos operativos mensuales: 12,000€

La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%.
¿Es una buena decisión financiera?"""

    prompt_analisis = f"""Analiza este caso de negocio paso a paso:

{caso_negocio}

Estructura tu análisis:
1. Calcula métricas del escenario actual
2. Calcula métricas del escenario propuesto
3. Compara ingresos y costos
4. Considera factores adicionales
5. Proporciona recomendación fundamentada

Análisis detallado:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("CASO DE NEGOCIO:")
        print(caso_negocio)
        print("\nANÁLISIS PASO A PASO:")
        print(response.content)

        # Verificar completitud del análisis
        analisis = response.content.lower()
        elementos_clave = [
            'ingresos', 'costos', 'beneficio', 'actual', 'propuesto',
            'recomendación', 'conversión', 'usuarios'
        ]
        elementos_presentes = sum(1 for elemento in elementos_clave if elemento in analisis)

        print(f"\n=== COMPLETITUD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave cubiertos: {elementos_presentes}/{len(elementos_clave)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 6 else 'Parcial'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis complejo
cot_analisis_complejo()
# Out:
# === CoT PARA ANÁLISIS COMPLEJO ===
# CASO DE NEGOCIO:
# Una startup de software tiene las siguientes métricas:
#     - 10,000 usuarios activos mensuales
#     - Tasa de conversión a premium: 5%
#     - Precio premium: 29€/mes
#     - Costo de adquisición por usuario: 15€
#     - Retención mensual: 85%
#     - Costos operativos mensuales: 12,000€
#
# La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%.
# ¿Es una buena decisión financiera?
#
# ANÁLISIS PASO A PASO:
# ### **Análisis del Caso de Negocio: Reducción de Precio Premium**
#
# #### **1. Métricas del Escenario Actual**
# - **Usuarios activos mensuales (UAM):** 10,000
# - **Tasa de conversión a premium:** 5% → **500 usuarios premium/mes** (10,000 × 0.05).
# - **Ingresos mensuales por premium:** 500 × 29€ = **14,500€**.
# - **Costos operativos mensuales:** 12,000€.
# - **Costo de adquisición por usuario (CAC):** 15€ → **Costo total de adquisición:** 10,000 × 15€ = **150,000€/mes**.
# - **Retención mensual:** 85% → **Usuarios retenidos al mes:** 10,000 × 0.85 = **8,500** (pero no afecta directamente los ingresos en este análisis mensual).
#
# **Margen bruto mensual:**
# - Ingresos - Costos operativos = 14,500€ - 12,000€ = **2,500€** (antes de impuestos y otros gastos).
#
# ---
#
# #### **2. Métricas del Escenario Propuesto (Precio reducido a 19€/mes)**
# - **Nueva tasa de conversión:** 8% → **800 usuarios premium/mes** (10,000 × 0.08).
# - **Ingresos mensuales por premium:** 800 × 19€ = **15,200€**.
# - **Costos operativos:** Siguen siendo 12,000€ (no cambian).
# - **CAC:** Sigue siendo 15€ (no hay información de que cambie).
#
# **Margen bruto mensual:**
# - Ingresos - Costos operativos = 15,200€ - 12,000€ = **3,200€**.
#
# ---
#
# #### **3. Comparación de Ingresos y Costos**
# | Métrica                     | Escenario Actual | Escenario Propuesto | Diferencia |
# |-----------------------------|------------------|---------------------|------------|
# | Usuarios premium/mes        | 500              | 800                 | +300       |
# | Ingresos premium/mes        | 14,500€          | 15,200€             | +700€      |
# | Margen bruto/mes            | 2,500€           | 3,200€              | +700€      |
# | CAC total/mes               | 150,000€         | 150,000€            | 0€         |
#
# **Conclusión financiera:**
# - El margen bruto **aumenta en 700€/mes** (de 2,500€ a 3,200€).
# - Los ingresos premium **aumentan en 700€/mes** (de 14,500€ a 15,200€).
# - El CAC se mantiene igual, por lo que no hay impacto negativo en la rentabilidad por usuario.
#
# ---
#
# #### **4. Factores Adicionales a Considerar**
# 1. **Elasticidad de la demanda:**
#    - La reducción de precio del 34% (de 29€ a 19€) genera un aumento del 60% en conversiones (de 5% a 8%).
#    - Esto sugiere que el mercado es **sensible al precio**, pero no se sabe si la elasticidad se mantendrá a largo plazo.
#
# 2. **Valor de Vida del Cliente (LTV):**
#    - Si la retención es del 85%, el LTV se calcula como:
#      - **LTV actual:** (29€ × 12 meses) × 0.85 = **296.4€**.
#      - **LTV propuesto:** (19€ × 12 meses) × 0.85 = **193.8€**.
#    - Aunque el LTV disminuye, el aumento en el número de usuarios premium compensa la reducción en el precio.
#
# 3. **Impacto en la percepción de valor:**
#    - Reducir el precio podría **devaluar la percepción del producto** (ej.: "si antes valía 29€, ¿por qué ahora cuesta 19€?").
#    - Podría atraer a usuarios menos comprometidos, aumentando la rotación.
#
# 4. **Crecimiento futuro:**
#    - Si la conversión aumenta al 8%, la base de usuarios premium crece, lo que podría generar más ingresos a largo plazo (ej.: upselling, referencias).
#    - Sin embargo, si la retención baja (por usuarios menos comprometidos), el LTV podría reducirse más.
#
# 5. **Competencia:**
#    - Si los competidores tienen precios similares, esta estrategia podría ser necesaria para mantener la competitividad.
#    - Si el producto es premium, reducir el precio podría **confundir a la audiencia objetivo**.
#
# 6. **Costos ocultos:**
#    - ¿Aumentarán los costos operativos con más usuarios premium? (ej.: soporte, servidores).
#    - ¿Habrá que invertir en marketing para comunicar el cambio de precio?
#
# ---
#
# #### **5. Recomendación Fundamentada**
# **La reducción de precio es una decisión financiera positiva en el corto plazo**, ya que:
# ✅ **Aumenta el margen bruto en 700€/mes** (de 2,500€ a 3,200€).
# ✅ **No afecta el CAC**, por lo que la rentabilidad por usuario se mantiene.
# ✅ **Puede acelerar el crecimiento** si la elasticidad de la demanda se mantiene.
#
# **Sin embargo, se recomienda:**
# ⚠ **Monitorear la retención y el LTV** para asegurarse de que no disminuyan significativamente.
# ⚠ **Evaluar el impacto en la percepción de valor** (ej.: encuestas a usuarios, pruebas A/B con diferentes precios).
# ⚠ **Considerar un enfoque híbrido**, como ofrecer un precio reducido solo para nuevos usuarios o en campañas específicas.
# ⚠ **Analizar el ROI a largo plazo** (ej.: ¿el aumento en usuarios premium compensa la reducción en LTV?).
#
# **Alternativas:**
# - **Prueba piloto:** Implementar la reducción de precio solo en un segmento de usuarios (ej.: nuevos clientes) para medir el impacto.
# - **A/B Testing:** Comparar conversiones y retención con ambos precios durante 1-2 meses.
# - **Estrategia de upselling:** Mantener el precio premium para usuarios existentes y ofrecer el precio reducido solo a nuevos clientes.
#
# **Conclusión final:**
# **Sí es una buena decisión financiera en el corto plazo**, pero debe implementarse con precaución y seguimiento continuo para evitar efectos negativos a largo plazo.
#
# === COMPLETITUD DEL ANÁLISIS ===
# ✓ Elementos clave cubiertos: 7/8
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Técnicas Avanzadas de CoT

# %%
# Técnica 1: CoT con Auto-Verificación
def cot_con_verificacion():
    print("=== CoT CON AUTO-VERIFICACIÓN ===")

    problema = "Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?"

    prompt_verificacion = f"""Resuelve este problema paso a paso y luego verifica tu respuesta:

{problema}

PASO 1 - RESOLUCIÓN:
Piensa paso a paso para encontrar la solución.

PASO 2 - VERIFICACIÓN:
Revisa tu cálculo usando un método diferente o verificando que los números tienen sentido.

PASO 3 - RESPUESTA FINAL:
Confirma tu respuesta final.

Proceso completo:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_verificacion)])
        print("PROBLEMA:")
        print(problema)
        print("\nSOLUCIÓN CON AUTO-VERIFICACIÓN:")
        print(response.content)

        # Verificar estructura
        contenido = response.content.lower()
        tiene_resolucion = 'paso 1' in contenido or 'resolución' in contenido
        tiene_verificacion = 'paso 2' in contenido or 'verificación' in contenido
        tiene_final = 'paso 3' in contenido or 'final' in contenido

        print("\n=== ESTRUCTURA ===")
        print(f"✓ Resolución: {'Sí' if tiene_resolucion else 'No'}")
        print(f"✓ Verificación: {'Sí' if tiene_verificacion else 'No'}")
        print(f"✓ Respuesta final: {'Sí' if tiene_final else 'No'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar CoT con verificación
cot_con_verificacion()
# Out:
# === CoT CON AUTO-VERIFICACIÓN ===
# PROBLEMA:
# Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?
#
# SOLUCIÓN CON AUTO-VERIFICACIÓN:
# **PASO 1 - RESOLUCIÓN:**
#
# Para resolver este problema, seguiremos estos pasos:
#
# 1. **Determinar la tasa de llenado de cada bomba:**
#    - La bomba A llena la piscina en 4 horas, por lo que su tasa de llenado es \( \frac{1}{4} \) de la piscina por hora.
#    - La bomba B llena la piscina en 6 horas, por lo que su tasa de llenado es \( \frac{1}{6} \) de la piscina por hora.
#
# 2. **Calcular la tasa combinada de llenado:**
#    - Cuando ambas bombas trabajan juntas, sus tasas se suman:
#      \[
#      \text{Tasa combinada} = \frac{1}{4} + \frac{1}{6}
#      \]
#    - Para sumar las fracciones, encontramos un denominador común (que es 12):
#      \[
#      \frac{1}{4} = \frac{3}{12}, \quad \frac{1}{6} = \frac{2}{12}
#      \]
#      \[
#      \text{Tasa combinada} = \frac{3}{12} + \frac{2}{12} = \frac{5}{12} \text{ de la piscina por hora}
#      \]
#
# 3. **Calcular el tiempo necesario para llenar la piscina:**
#    - Si juntas llenan \( \frac{5}{12} \) de la piscina en 1 hora, el tiempo \( t \) para llenar 1 piscina completa es:
#      \[
#      t = \frac{1}{\frac{5}{12}} = \frac{12}{5} \text{ horas}
#      \]
#    - Convertimos \( \frac{12}{5} \) horas a horas y minutos:
#      \[
#      \frac{12}{5} = 2.4 \text{ horas} = 2 \text{ horas y } 0.4 \times 60 \text{ minutos} = 2 \text{ horas y } 24 \text{ minutos}
#      \]
#
# **PASO 2 - VERIFICACIÓN:**
#
# Verificaremos el cálculo usando un método alternativo: el método de la tasa de trabajo.
#
# 1. **Asumir que la piscina tiene un volumen de 12 litros (un múltiplo común de 4 y 6 para simplificar):**
#    - La bomba A llena 12 litros en 4 horas, por lo que su tasa es \( \frac{12}{4} = 3 \) litros/hora.
#    - La bomba B llena 12 litros en 6 horas, por lo que su tasa es \( \frac{12}{6} = 2 \) litros/hora.
#    - La tasa combinada es \( 3 + 2 = 5 \) litros/hora.
#
# 2. **Calcular el tiempo para llenar 12 litros a 5 litros/hora:**
#    \[
#    t = \frac{12}{5} = 2.4 \text{ horas} = 2 \text{ horas y } 24 \text{ minutos}
#    \]
#
# El resultado coincide con el obtenido anteriormente, lo que verifica la solución.
#
# **PASO 3 - RESPUESTA FINAL:**
#
# Las dos bombas trabajando juntas llenan la piscina en \( \frac{12}{5} \) horas, que es equivalente a **2 horas y 24 minutos**.
#
# **Respuesta final:**
# \[
# \boxed{2 \text{ horas y } 24 \text{ minutos}}
# \]
#
# === ESTRUCTURA ===
# ✓ Resolución: Sí
# ✓ Verificación: Sí
# ✓ Respuesta final: Sí

# %%
# Técnica 2: CoT Multi-Perspectiva
def cot_multi_perspectiva():
    print("=== CoT MULTI-PERSPECTIVA ===")

    dilema = """Una empresa de delivery está considerando implementar un algoritmo de IA
    para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos
    de repartidores. ¿Debería implementarlo?"""

    prompt_multi = f"""Analiza este dilema desde múltiples perspectivas:

{dilema}

Analiza paso a paso desde cada perspectiva:

PERSPECTIVA 1 - FINANCIERA:
- Beneficios económicos
- Costos de implementación
- ROI a corto y largo plazo

PERSPECTIVA 2 - SOCIAL/ÉTICA:
- Impacto en empleados
- Responsabilidad social corporativa
- Percepción pública

PERSPECTIVA 3 - ESTRATÉGICA:
- Competitividad del mercado
- Innovación tecnológica
- Sostenibilidad del negocio

SÍNTESIS:
- Integra las perspectivas
- Propone soluciones alternativas
- Recomienda curso de acción

Análisis completo:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_multi)])
        print("DILEMA EMPRESARIAL:")
        print(dilema)
        print("\nANÁLISIS MULTI-PERSPECTIVA:")
        print(response.content)

        # Verificar cobertura de perspectivas
        analisis = response.content.lower()
        perspectivas = ['financiera', 'social', 'ética', 'estratégica', 'síntesis']
        perspectivas_cubiertas = sum(1 for p in perspectivas if p in analisis)

        print(f"\n=== COBERTURA DEL ANÁLISIS ===")
        print(f"✓ Perspectivas cubiertas: {perspectivas_cubiertas}/{len(perspectivas)}")
        print(f"✓ Análisis integral: {'Sí' if perspectivas_cubiertas >= 4 else 'Parcial'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis multi-perspectiva
cot_multi_perspectiva()
# Out:
# === CoT MULTI-PERSPECTIVA ===
# DILEMA EMPRESARIAL:
# Una empresa de delivery está considerando implementar un algoritmo de IA
#     para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos
#     de repartidores. ¿Debería implementarlo?
#
# ANÁLISIS MULTI-PERSPECTIVA:
# ### **Análisis Multiperspectivo de la Implementación del Algoritmo de IA en la Empresa de Delivery**
#
# ---
#
# ## **PERSPECTIVA 1: FINANCIERA**
# ### **1. Beneficios económicos**
# - **Reducción de costos operativos**: Un ahorro del **20%** en logística (combustible, mantenimiento de vehículos, salarios indirectos) podría traducirse en millones de dólares anuales, dependiendo del volumen de entregas.
# - **Mayor eficiencia**: Menos tiempo en rutas = más entregas por día, lo que podría aumentar ingresos si se aprovecha la capacidad liberada.
# - **Escalabilidad**: La IA permite adaptarse a picos de demanda (ej.: Black Friday) sin contratar personal temporal.
#
# ### **2. Costos de implementación**
# - **Inversión inicial**: Desarrollo/adquisición del algoritmo, integración con sistemas existentes, capacitación del personal técnico.
# - **Mantenimiento y actualización**: La IA requiere datos continuos, ajustes algorítmicos y posibles fallos iniciales que podrían generar costos imprevistos.
# - **Costos ocultos**: Posible resistencia al cambio por parte de empleados (baja productividad temporal) o clientes (errores en entregas).
#
# ### **3. ROI (Retorno de Inversión)**
# - **Corto plazo (1-2 años)**:
#   - **Negativo**: Altos costos iniciales y posible pérdida de ingresos por descontento laboral o errores.
#   - **Positivo**: Si el algoritmo funciona bien, el ahorro en costos podría compensar la inversión en menos de 2 años.
# - **Largo plazo (3-5 años)**:
#   - **Positivo**: Si la empresa reinvierte los ahorros en innovación o expansión, el ROI sería alto.
#   - **Riesgo**: Si la competencia adopta tecnologías similares, la empresa podría quedarse atrás.
#
# **Conclusión financiera**:
# El proyecto es **rentable a largo plazo**, pero requiere un **plan de transición financiera** para absorber los costos iniciales y evitar pérdidas operativas durante la implementación.
#
# ---
#
# ## **PERSPECTIVA 2: SOCIAL/ÉTICA**
# ### **1. Impacto en empleados**
# - **Pérdida de empleos**: 100 repartidores afectados directamente. Esto genera:
#   - **Desempleo estructural**: Muchos podrían no encontrar trabajo fácilmente en un sector con alta rotación.
#   - **Impacto psicológico**: Estrés, pérdida de ingresos y posible estigma social.
# - **Reubicación**: Algunos podrían ser reasignados a otros roles (ej.: gestión de flotas, atención al cliente), pero no todos tendrían habilidades transferibles.
#
# ### **2. Responsabilidad Social Corporativa (RSC)**
# - **Deber ético**: La empresa tiene una obligación moral con sus empleados, especialmente si estos han contribuido al crecimiento de la compañía.
# - **Alternativas a despidos**:
#   - **Reentrenamiento**: Programas de capacitación en nuevas tecnologías (ej.: manejo de drones, gestión de datos).
#   - **Transición gradual**: Reducir plantilla solo cuando los empleados puedan jubilarse o encontrar otros empleos.
#   - **Compensación**: Indemnizaciones justas, apoyo en recolocación o creación de cooperativas de repartidores.
#
# ### **3. Percepción pública**
# - **Reputación**: Si la empresa despide empleados sin compensación, podría enfrentar:
#   - **Boicot de clientes** (especialmente en mercados con conciencia social).
#   - **Críticas en medios y redes sociales**, afectando la marca empleadora.
# - **Ventaja competitiva**: Si la empresa maneja el cambio con transparencia y apoyo a los empleados, podría mejorar su imagen como "innovadora y responsable".
#
# **Conclusión ética**:
# La empresa **debe priorizar alternativas al despido masivo**, como reentrenamiento o recolocación. Si no es posible, debe ofrecer **compensaciones justas y transparencia** para mitigar el impacto social.
#
# ---
#
# ## **PERSPECTIVA 3: ESTRATÉGICA**
# ### **1. Competitividad del mercado**
# - **Ventaja competitiva**: La optimización de rutas puede reducir tiempos de entrega, mejorando la satisfacción del cliente y atrayendo más pedidos.
# - **Presión del mercado**: Si competidores como **Glovo, Uber Eats o Amazon** ya usan IA, la empresa podría quedarse atrás si no adopta la tecnología.
# - **Diferenciación**: Podría posicionarse como **"la empresa más eficiente y tecnológica"** del sector.
#
# ### **2. Innovación tecnológica**
# - **Oportunidad de liderazgo**: Ser pionero en logística con IA puede atraer inversores y socios estratégicos.
# - **Riesgo de obsolescencia**: Si no innova, podría ser superada por startups o empresas con modelos más ágiles.
#
# ### **3. Sostenibilidad del negocio**
# - **Modelo escalable**: La IA permite crecer sin aumentar proporcionalmente los costos laborales.
# - **Adaptabilidad**: En un futuro con regulaciones más estrictas (ej.: impuestos a emisiones de CO₂), la optimización de rutas puede ser clave para cumplir con normas ambientales.
# - **Dependencia tecnológica**: Si el algoritmo falla, la empresa podría enfrentar crisis operativas.
#
# **Conclusión estratégica**:
# La implementación de la IA es **necesaria para la supervivencia a largo plazo**, pero debe hacerse de manera **gradual y con un plan de transición** para no perder talento humano ni reputación.
#
# ---
#
# ## **SÍNTESIS: INTEGRACIÓN DE PERSPECTIVAS**
# ### **1. Conflictos clave**
# | **Perspectiva**       | **Beneficios**                          | **Riesgos**                              |
# |-----------------------|----------------------------------------|------------------------------------------|
# | **Financiera**        | Ahorro del 20% en costos, mayor eficiencia | Altos costos iniciales, posible resistencia |
# | **Social/Ética**      | Innovación, posible mejora de imagen   | Desempleo, impacto en empleados          |
# | **Estratégica**       | Ventaja competitiva, escalabilidad     | Obsolescencia si no se implementa        |
#
# ### **2. Soluciones alternativas**
# Para equilibrar los intereses, la empresa podría considerar:
#
# #### **Opción 1: Implementación gradual con reentrenamiento**
# - **Fase 1 (0-12 meses)**: Implementar IA en rutas piloto, reentrenar al 30% de los repartidores para nuevos roles (ej.: supervisores de flota, analistas de datos).
# - **Fase 2 (12-24 meses)**: Expandir la IA a todas las rutas, pero con **reducción progresiva de plantilla** (ej.: no renovar contratos temporales, ofrecer jubilaciones anticipadas).
# - **Fase 3 (24+ meses)**: Evaluar impacto y ajustar.
#
# #### **Opción 2: Modelo híbrido (IA + repartidores humanos)**
# - Usar IA para **rutas principales** y mantener repartidores para **zonas rurales o servicios premium** (ej.: entregas en menos de 30 minutos).
# - Esto reduce costos pero **no elimina empleos por completo**.
#
# #### **Opción 3: Externalización con responsabilidad social**
# - Crear una **cooperativa de repartidores** donde la empresa subcontrate servicios a ex-empleados, garantizando ingresos estables.
# - Ejemplo: Empresas como **Deliveroo en Reino Unido** han probado modelos similares.
#
# #### **Opción 4: Inversión en otros sectores**
# - Si la empresa tiene recursos, podría **reubicar a los empleados en áreas con demanda** (ej.: logística inversa, almacenes automatizados).
#
# ### **3. Recomendación final**
# **La empresa DEBERÍA implementar el algoritmo de IA, pero con un plan ético y estratégico que minimice el impacto negativo.**
#
# #### **Curso de acción propuesto:**
# 1. **Transparencia y comunicación**:
#    - Informar a los empleados con **6-12 meses de antelación** sobre los cambios.
#    - Explicar cómo la IA **mejorará la empresa** y qué oportunidades habrá para ellos.
#
# 2. **Programas de reentrenamiento**:
#    - Ofrecer cursos en **gestión de datos, logística avanzada o atención al cliente**.
#    - Colaborar con **universidades o centros de formación** para certificaciones.
#
# 3. **Reducción gradual de plantilla**:
#    - No despedir de golpe, sino con **indemnizaciones justas y apoyo en recolocación**.
#    - Priorizar la **jubilación anticipada** para empleados cercanos a la edad de retiro.
#
# 4. **Piloto controlado**:
#    - Implementar la IA en **una región pequeña** para medir impacto antes de escalar.
#
# 5. **Compensación social**:
#    - Crear un **fondo de transición** para empleados afectados.
#    - Invertir en **proyectos comunitarios** (ej.: talleres de emprendimiento para ex-repartidores).
#
# 6. **Monitoreo y ajuste**:
#    - Evaluar cada 6 meses el impacto en **costos, satisfacción del cliente y moral del equipo**.
#    - Si los resultados no son los esperados, **revertir o ajustar el modelo**.
#
# ---
# ### **Conclusión final**
# La implementación de la IA es **inevitable en un mercado competitivo**, pero su éxito depende de **cómo se gestione el cambio humano**. Una empresa que prioriza **eficiencia sin descuidar a sus empleados** no solo será más rentable, sino también más **respetada y sostenible** a largo plazo.
#
# **Recomendación final:**
# ✅ **Implementar la IA, pero con un plan de transición ético y gradual.**
# ❌ **No implementarla** significaría perder competitividad.
# ⚠️ **Hacerlo sin plan** generaría crisis social y reputacional.
#
# **Ejemplo de éxito:**
# Empresas como **UPS** han usado IA para optimizar rutas (ahorrando **$50 millones anuales**) mientras reentrenan a empleados en nuevas tecnologías. Este modelo podría ser replicado.
#
# === COBERTURA DEL ANÁLISIS ===
# ✓ Perspectivas cubiertas: 5/5
# ✓ Análisis integral: Sí

# %% [markdown]
# ## CoT para Debugging de Código
#
# Una aplicación práctica muy útil: usar CoT para analizar y debuggear código.

# %%
# CoT para debugging de código
def cot_debugging():
    print("=== CoT PARA DEBUGGING DE CÓDIGO ===")

    codigo_con_bug = '''def calcular_promedio(numeros):
    total = 0
    for numero in numeros:
        total += numero
    promedio = total / len(numeros)
    return promedio

# Uso
datos = []
resultado = calcular_promedio(datos)
print(f"El promedio es: {resultado}")'''

    prompt_debugging = f"""Analiza este código paso a paso para encontrar problemas:

```python
{codigo_con_bug}
```

PASO 1 - COMPRENSIÓN:
¿Qué se supone que hace este código?

PASO 2 - ANÁLISIS LÍNEA POR LÍNEA:
Examina cada línea en busca de problemas potenciales.

PASO 3 - IDENTIFICACIÓN DE PROBLEMAS:
¿Qué errores o problemas específicos encuentras?

PASO 4 - CASOS PROBLEMÁTICOS:
¿En qué situaciones fallaría este código?

PASO 5 - SOLUCIÓN:
¿Cómo arreglarías estos problemas?

Análisis de debugging:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_debugging)])
        print("CÓDIGO A ANALIZAR:")
        print(codigo_con_bug)
        print("\nANÁLISIS DE DEBUGGING:")
        print(response.content)

        # Verificar si encontró el problema principal
        analisis = response.content.lower()
        encontro_division_cero = any(term in analisis for term in ['división', 'cero', 'vacía', 'empty'])
        propuso_solucion = 'if' in analisis or 'len(' in analisis or 'excepción' in analisis

        print(f"\n=== EFECTIVIDAD DEL DEBUGGING ===")
        print(f"✓ Identificó división por cero: {'Sí' if encontro_division_cero else 'No'}")
        print(f"✓ Propuso solución: {'Sí' if propuso_solucion else 'No'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar debugging
cot_debugging()
# Out:
# === CoT PARA DEBUGGING DE CÓDIGO ===
# CÓDIGO A ANALIZAR:
# def calcular_promedio(numeros):
#     total = 0
#     for numero in numeros:
#         total += numero
#     promedio = total / len(numeros)
#     return promedio
#
# # Uso
# datos = []
# resultado = calcular_promedio(datos)
# print(f"El promedio es: {resultado}")
#
# ANÁLISIS DE DEBUGGING:
# ### **PASO 1 - COMPRENSIÓN**
# El código define una función `calcular_promedio(numeros)` que:
# 1. Inicializa una variable `total` en 0.
# 2. Itera sobre una lista de números (`numeros`), sumando cada uno a `total`.
# 3. Calcula el promedio dividiendo `total` entre la cantidad de elementos en `numeros` (`len(numeros)`).
# 4. Retorna el promedio.
#
# Luego, se usa la función con una lista vacía (`datos = []`) y se imprime el resultado.
#
# ---
#
# ### **PASO 2 - ANÁLISIS LÍNEA POR LÍNEA**
#
# 1. **Definición de la función `calcular_promedio(numeros)`**:
#    - No hay problemas sintácticos aquí. La función está bien estructurada.
#
# 2. **Línea `total = 0`**:
#    - Correcto. Inicializa el acumulador para la suma.
#
# 3. **Bucle `for numero in numeros:`**:
#    - Correcto. Itera sobre cada elemento de la lista `numeros`.
#    - **Problema potencial**: Si `numeros` no es una lista (ej. `None`, un entero, etc.), el bucle fallará.
#
# 4. **Línea `promedio = total / len(numeros)`**:
#    - **Problema crítico**: Si `numeros` está vacío (`len(numeros) == 0`), esto generará una **división por cero** (`ZeroDivisionError`).
#
# 5. **Línea `return promedio`**:
#    - Correcto si la función llega hasta aquí. Pero si hay una división por cero, el código fallará antes.
#
# 6. **Uso de la función**:
#    - `datos = []`: Lista vacía.
#    - `resultado = calcular_promedio(datos)`: Llamará a la función con una lista vacía.
#    - `print(f"El promedio es: {resultado}")`: Imprimirá el resultado.
#
# ---
#
# ### **PASO 3 - IDENTIFICACIÓN DE PROBLEMAS**
#
# 1. **División por cero**:
#    - Si `numeros` está vacío, `len(numeros)` es 0, y `total / len(numeros)` intentará dividir por 0, lanzando `ZeroDivisionError`.
#
# 2. **Falta de validación de entrada**:
#    - La función no verifica si `numeros` es `None`, no es una lista, o contiene elementos no numéricos (ej. strings).
#    - Ejemplo de entrada problemática:
#      - `calcular_promedio(None)` → Error (`TypeError`).
#      - `calcular_promedio(["a", "b"])` → Error (`TypeError` al sumar strings).
#
# 3. **Falta de manejo de excepciones**:
#    - No hay bloques `try-except` para capturar errores como `ZeroDivisionError` o `TypeError`.
#
# ---
#
# ### **PASO 4 - CASOS PROBLEMÁTICOS**
#
# | **Entrada**               | **Problema**                          | **Error**                     |
# |---------------------------|---------------------------------------|-------------------------------|
# | `[]` (lista vacía)        | División por cero                     | `ZeroDivisionError`           |
# | `None`                    | `numeros` no es iterable              | `TypeError`                   |
# | `["a", "b"]`              | Suma de strings                       | `TypeError`                   |
# | `123` (número)            | `numeros` no es iterable              | `TypeError`                   |
# | `[1, 2, "tres"]`          | Mezcla de tipos                       | `TypeError`                   |
#
# ---
#
# ### **PASO 5 - SOLUCIÓN**
#
# **Versión mejorada del código**:
# ```python
# def calcular_promedio(numeros):
#     # Validar entrada
#     if not isinstance(numeros, list):
#         raise TypeError("La entrada debe ser una lista de números.")
#
#     if len(numeros) == 0:
#         raise ValueError("La lista no puede estar vacía.")
#
#     total = 0
#     for numero in numeros:
#         if not isinstance(numero, (int, float)):
#             raise TypeError(f"Todos los elementos deben ser números. Encontrado: {numero}")
#         total += numero
#
#     promedio = total / len(numeros)
#     return promedio
#
# # Uso con manejo de excepciones
# try:
#     datos = []
#     resultado = calcular_promedio(datos)
#     print(f"El promedio es: {resultado}")
# except ZeroDivisionError:
#     print("Error: La lista está vacía.")
# except TypeError as e:
#     print(f"Error: {e}")
# except ValueError as e:
#     print(f"Error: {e}")
# ```
#
# **Mejoras realizadas**:
# 1. **Validación de entrada**:
#    - Verifica que `numeros` sea una lista.
#    - Verifica que la lista no esté vacía.
#    - Verifica que todos los elementos sean números (`int` o `float`).
#
# 2. **Manejo de excepciones**:
#    - Usa `try-except` para capturar errores y mostrar mensajes claros al usuario.
#
# 3. **Mensajes de error descriptivos**:
#    - Indica exactamente qué salió mal (ej. "La lista está vacía" o "Todos los elementos deben ser números").
#
# 4. **Robustez**:
#    - Ahora el código no fallará silenciosamente y dará feedback útil al usuario.
#
# ---
#
# ### **Conclusión**
# El código original tenía un **error crítico** (división por cero) y **falta de validación de entrada**. La versión mejorada es más robusta y segura, manejando casos edge-case y proporcionando mensajes de error claros.
#
# === EFECTIVIDAD DEL DEBUGGING ===
# ✓ Identificó división por cero: Sí
# ✓ Propuso solución: Sí

# %% [markdown]
# # Ejercicio con Chain of Thought

# %%
# Ejercicio final: Diseña tu propio CoT prompt
def ejercicio_cot():
    print("=== EJERCICIO: DISEÑA TU CoT PROMPT ===")
    print("\nTarea: Crear un sistema CoT para análisis de inversión")
    print("\nEscenario:")
    print("Una persona tiene 10,000€ para invertir y está considerando tres opciones:")
    print("1. Acciones de tech (retorno esperado 12% anual, riesgo alto)")
    print("2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)")
    print("3. Fondo mixto (retorno 7% anual, riesgo medio)")
    print("\nLa persona es joven (25 años) y puede asumir riesgo moderado.")

    # Template para el estudiante
    template_cot = """
    # TU PROMPT CoT AQUÍ:

    Analiza esta decisión de inversión paso a paso:

    [ESCENARIO]

    PASO 1 - PERFIL DEL INVERSOR:
    - Analiza edad, tolerancia al riesgo, horizonte temporal

    PASO 2 - ANÁLISIS DE OPCIONES:
    - Evalúa cada opción: retorno, riesgo, liquidez

    PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
    - Considera combinar opciones

    PASO 4 - RECOMENDACIÓN:
    - Proporciona recomendación específica con justificación

    Análisis de inversión:
    """

    print("\nDiseña un prompt CoT estructurado:")
    print(template_cot)

    # Prompt de ejemplo bien diseñado
    prompt_ejemplo = """Analiza esta decisión de inversión usando razonamiento paso a paso:

SITUACIÓN:
Inversor de 25 años con 10,000€ considerando:
- Acciones tech: 12% retorno anual, riesgo alto
- Bonos: 3% retorno anual, riesgo bajo
- Fondo mixto: 7% retorno anual, riesgo medio
Tolerancia: riesgo moderado

PASO 1 - PERFIL DEL INVERSOR:
Analiza edad, horizonte temporal y tolerancia al riesgo.

PASO 2 - EVALUACIÓN DE OPCIONES:
Para cada opción, calcula:
- Valor esperado en 10 años
- Nivel de riesgo vs. perfil
- Pros y contras específicos

PASO 3 - ESTRATEGIA DE PORTFOLIO:
Considera distribución óptima entre opciones basada en:
- Diversificación de riesgo
- Maximización de retorno ajustado por riesgo
- Liquidez y flexibilidad

PASO 4 - RECOMENDACIÓN FINAL:
Proporciona distribución específica (porcentajes) con:
- Justificación detallada
- Proyección a 10 años
- Consideraciones adicionales

Análisis completo:"""

    print("\n=== PROMPT DE REFERENCIA ===")
    print(prompt_ejemplo)

    # Ejecutar el prompt ejemplo
    print("\n=== RESULTADO DEL ANÁLISIS ===")
    try:
        response = llm.invoke([HumanMessage(content=prompt_ejemplo)])
        print(response.content)

        # Análisis de la respuesta
        analisis = response.content.lower()
        elementos = ['perfil', 'evaluación', 'portfolio', 'recomendación', '%', '€', 'años']
        elementos_presentes = sum(1 for elem in elementos if elem in analisis)

        print(f"\n=== CALIDAD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave: {elementos_presentes}/{len(elementos)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 5 else 'Parcial'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar ejercicio
ejercicio_cot()
# Out:
# === EJERCICIO: DISEÑA TU CoT PROMPT ===
#
# Tarea: Crear un sistema CoT para análisis de inversión
#
# Escenario:
# Una persona tiene 10,000€ para invertir y está considerando tres opciones:
# 1. Acciones de tech (retorno esperado 12% anual, riesgo alto)
# 2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)
# 3. Fondo mixto (retorno 7% anual, riesgo medio)
#
# La persona es joven (25 años) y puede asumir riesgo moderado.
#
# Diseña un prompt CoT estructurado:
#
#     # TU PROMPT CoT AQUÍ:
#
#     Analiza esta decisión de inversión paso a paso:
#
#     [ESCENARIO]
#
#     PASO 1 - PERFIL DEL INVERSOR:
#     - Analiza edad, tolerancia al riesgo, horizonte temporal
#
#     PASO 2 - ANÁLISIS DE OPCIONES:
#     - Evalúa cada opción: retorno, riesgo, liquidez
#
#     PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
#     - Considera combinar opciones
#
#     PASO 4 - RECOMENDACIÓN:
#     - Proporciona recomendación específica con justificación
#
#     Análisis de inversión:
#
#
# === PROMPT DE REFERENCIA ===
# Analiza esta decisión de inversión usando razonamiento paso a paso:
#
# SITUACIÓN:
# Inversor de 25 años con 10,000€ considerando:
# - Acciones tech: 12% retorno anual, riesgo alto
# - Bonos: 3% retorno anual, riesgo bajo
# - Fondo mixto: 7% retorno anual, riesgo medio
# Tolerancia: riesgo moderado
#
# PASO 1 - PERFIL DEL INVERSOR:
# Analiza edad, horizonte temporal y tolerancia al riesgo.
#
# PASO 2 - EVALUACIÓN DE OPCIONES:
# Para cada opción, calcula:
# - Valor esperado en 10 años
# - Nivel de riesgo vs. perfil
# - Pros y contras específicos
#
# PASO 3 - ESTRATEGIA DE PORTFOLIO:
# Considera distribución óptima entre opciones basada en:
# - Diversificación de riesgo
# - Maximización de retorno ajustado por riesgo
# - Liquidez y flexibilidad
#
# PASO 4 - RECOMENDACIÓN FINAL:
# Proporciona distribución específica (porcentajes) con:
# - Justificación detallada
# - Proyección a 10 años
# - Consideraciones adicionales
#
# Análisis completo:
#
# === RESULTADO DEL ANÁLISIS ===
# ### **Análisis de Decisión de Inversión: Inversor de 25 años con 10,000€**
# **Objetivo:** Maximizar el retorno ajustado por riesgo, considerando un perfil de **riesgo moderado**, horizonte temporal de **10 años** y capital inicial de **10,000€**.
#
# ---
#
# ## **PASO 1: PERFIL DEL INVERSOR**
# ### **1.1. Edad y Horizonte Temporal**
# - **Edad:** 25 años.
#   - Ventaja: **Alto horizonte temporal** (10+ años), lo que permite asumir más riesgo para obtener mayores retornos.
#   - Flexibilidad: Puede recuperar pérdidas eventuales con tiempo.
# - **Horizonte de inversión:** 10 años.
#   - Suficiente para superar volatilidad de activos de riesgo (ej. acciones tech).
#   - Permite aprovechar el **interés compuesto** sin necesidad de liquidez inmediata.
#
# ### **1.2. Tolerancia al Riesgo**
# - **Riesgo moderado:**
#   - No quiere perder más del **20-30%** en un año malo.
#   - Prefiere evitar activos con alta volatilidad (ej. criptomonedas, acciones individuales de sectores volátiles).
#   - Busca un equilibrio entre crecimiento y estabilidad.
#
# ### **1.3. Objetivos Financieros**
# - **Crecimiento a largo plazo:** Prioriza acumulación de capital sobre ingresos pasivos.
# - **Flexibilidad:** Posible necesidad de retirar fondos antes de 10 años (ej. emergencias, oportunidades).
# - **Educación financiera:** Puede ser un buen momento para aprender sobre mercados sin exponerse demasiado.
#
# **Conclusión del perfil:**
# - **Perfil:** **Moderado-agresivo** (más cercano a moderado, pero con capacidad para asumir algo de riesgo).
# - **Estrategia:** **Diversificación** con énfasis en crecimiento, pero con protección contra caídas bruscas.
#
# ---
#
# ## **PASO 2: EVALUACIÓN DE OPCIONES INDIVIDUALES**
#
# | **Opción**       | **Retorno Anual** | **Riesgo** | **Liquidez** | **Pros**                          | **Contras**                          |
# |------------------|-------------------|------------|--------------|-----------------------------------|--------------------------------------|
# | **Acciones Tech** | 12%               | Alto       | Alta         | Alto potencial de crecimiento     | Volatilidad extrema, posible pérdida del 50%+ en crisis |
# | **Bonos**        | 3%                | Bajo       | Alta         | Estabilidad, bajo riesgo          | Retorno bajo, vulnerable a inflación |
# | **Fondo Mixto**  | 7%                | Medio      | Media-Alta   | Diversificación automática        | Menor retorno que acciones puras     |
#
# ### **2.1. Cálculo de Valor Esperado en 10 Años**
# *(Asumiendo reinversión de ganancias y sin impuestos)*
#
# | **Opción**       | **Retorno Anual** | **Valor en 10 años (10,000€)** | **Riesgo (Desviación Estándar)** |
# |------------------|-------------------|---------------------------------|----------------------------------|
# | **Acciones Tech** | 12%               | **31,058€**                     | ~25-30% anual (ej. -40% en 2022) |
# | **Bonos**        | 3%                | **13,439€**                     | ~5% anual                        |
# | **Fondo Mixto**  | 7%                | **19,672€**                     | ~12-15% anual                   |
#
# **Notas:**
# - Los bonos ofrecen **seguridad pero bajo crecimiento** (pérdida de poder adquisitivo por inflación).
# - Las acciones tech tienen **alto riesgo de pérdida permanente** (ej. burbujas, quiebras).
# - El fondo mixto es un **compromiso equilibrado**.
#
# ### **2.2. Análisis de Riesgo vs. Perfil**
# - **Acciones Tech:**
#   - **Riesgo inaceptable** para un perfil moderado (posible caída del 30-50% en un año).
#   - Solo recomendable si se asigna un **pequeño porcentaje** (ej. 10-20%) como "apuesta especulativa".
# - **Bonos:**
#   - **Demasiado conservador** para un inversor joven con horizonte largo.
#   - Podrían ser útiles para **estabilizar el portfolio**, pero no como activo principal.
# - **Fondo Mixto:**
#   - **Ajustado al perfil moderado**.
#   - Combina acciones (crecimiento) y bonos (estabilidad) en una proporción predefinida (ej. 60% acciones / 40% bonos).
#
# ---
#
# ## **PASO 3: ESTRATEGIA DE PORTFOLIO ÓPTIMA**
#
# ### **3.1. Diversificación y Asignación de Activos**
# **Objetivos:**
# 1. **Maximizar retorno ajustado por riesgo** (evitar activos con Sharpe Ratio negativo).
# 2. **Proteger contra caídas bruscas** (diversificación).
# 3. **Mantener liquidez** para oportunidades o emergencias.
#
# **Propuesta de Asset Allocation:**
# | **Activo**          | **% Portfolio** | **Razón**                                                                 |
# |---------------------|-----------------|---------------------------------------------------------------------------|
# | **Fondo Mixto**     | 60%             | Principal motor de crecimiento con riesgo controlado.                    |
# | **Bonos (Gobierno/Corporativos)** | 30% | Estabilidad y protección contra volatilidad.                              |
# | **Acciones Tech (ETF o índice)** | 10% | Exposición limitada a alto crecimiento (ej. Nasdaq-100 o S&P 500 Tech). |
#
# **Alternativas consideradas:**
# - **100% Fondo Mixto:** Retorno esperado ~7%, riesgo medio. **Opción válida pero menos optimizada.**
# - **80% Acciones / 20% Bonos:** Retorno esperado ~9-10%, pero riesgo alto (no recomendado para perfil moderado).
# - **40% Acciones / 40% Bonos / 20% REITs/Commodities:** Más diversificado, pero complejo para un inversor principiante.
#
# ### **3.2. Justificación de la Asignación**
# 1. **Fondo Mixto (60%):**
#    - **Ejemplo:** Un fondo como **Vanguard LifeStrategy 60% Equity** (60% acciones, 40% bonos).
#    - **Retorno esperado:** ~7% anual.
#    - **Riesgo:** Moderado (caídas máximas históricas ~20-25% en crisis).
#    - **Ventaja:** Gestión pasiva, bajo coste, diversificación automática.
#
# 2. **Bonos (30%):**
#    - **Ejemplo:** Bonos del Estado alemán o ETF de bonos corporativos (ej. **iShares Global Aggregate Bond**).
#    - **Función:** Reducir volatilidad global del portfolio.
#    - **Riesgo:** Bajo (pero sensible a subidas de tipos de interés).
#
# 3. **Acciones Tech (10%):**
#    - **Ejemplo:** ETF como **Invesco QQQ** (Nasdaq-100) o **iShares Global Tech**.
#    - **Razón:** Exposición limitada a sectores de alto crecimiento (IA, semiconductores, cloud).
#    - **Riesgo:** Alto, pero limitado a un 10% del portfolio.
#
# ### **3.3. Proyección a 10 Años**
# *(Simulación con retornos anuales compuestos y reinversión)*
#
# | **Escenario**       | **Retorno Anual** | **Valor Final (10,000€)** | **Probabilidad** |
# |---------------------|-------------------|----------------------------|------------------|
# | **Conservador**     | 5%                | **16,289€**                | 20%              |
# | **Base (esperado)** | 7%                | **19,672€**                | 50%              |
# | **Optimista**       | 9%                | **23,674€**                | 20%              |
# | **Pesimista**       | 3%                | **13,439€**                | 10%              |
#
# **Notas:**
# - El escenario **base (7%)** es el más probable con la asignación propuesta.
# - El **peor caso (3%)** ocurriría si los bonos rinden poco y las acciones tech caen.
# - **Mejor caso (9%)** si los mercados tech tienen un ciclo alcista prolongado.
#
# ---
#
# ## **PASO 4: RECOMENDACIÓN FINAL**
#
# ### **4.1. Distribución Recomendada**
# | **Activo**          | **% Portfolio** | **Ejemplo de Producto**               | **Objetivo**                     |
# |---------------------|-----------------|---------------------------------------|----------------------------------|
# | **Fondo Mixto**     | 60%             | Vanguard LifeStrategy 60% Equity      | Crecimiento estable              |
# | **Bonos**           | 30%             | iShares Global Aggregate Bond ETF     | Estabilidad y reducción de riesgo|
# | **Acciones Tech**   | 10%             | Invesco QQQ (Nasdaq-100)              | Exposición a alto crecimiento    |
#
# **Total:** **10,000€**
# - **6,000€** → Fondo Mixto
# - **3,000€** → Bonos
# - **1,000€** → Acciones Tech
#
# ### **4.2. Justificación Detallada**
# 1. **Enfoque en fondos indexados (60%):**
#    - **Bajo coste** (ej. TER < 0.3% anual).
#    - **Diversificación global** (evita dependencia de un solo mercado).
#    - **Gestión pasiva** (no requiere tiempo ni conocimiento avanzado).
#
# 2. **Bonos (30%):**
#    - **Protección contra caídas** del mercado de acciones.
#    - **Liquidez** (ETF de bonos son fáciles de vender).
#    - **Diversificación geográfica** (bonos europeos, estadounidenses, emergentes).
#
# 3. **Acciones Tech (10%):**
#    - **Exposición limitada a alto crecimiento** sin asumir riesgo excesivo.
#    - **Alternativa:** Si el inversor prefiere menos riesgo, puede reducir este porcentaje al **5%** y aumentar el fondo mixto al **65%**.
#
# ### **4.3. Proyección a 10 Años (Escenario Base)**
# - **Retorno anual esperado:** **7%**
# - **Valor final estimado:** **~19,672€** (sin aportaciones adicionales).
# - **Riesgo de pérdida en un año malo:** **~15-20%** (aceptable para perfil moderado).
#
# ### **4.4. Consideraciones Adicionales**
# 1. **Aportaciones periódicas:**
#    - Si el inversor puede añadir **200€/mes**, el valor final en 10 años podría superar **30,000€** (asumiendo 7% de retorno).
#
# 2. **Reequilibrio anual:**
#    - Cada año, ajustar los porcentajes para mantener la asignación (ej. vender parte de bonos si suben mucho y comprar más acciones).
#
# 3. **Fiscalidad:**
#    - En España, los fondos de inversión tienen ventajas fiscales (solo tributan al vender).
#    - Los ETFs de acumulación (reinversión automática) son ideales para diferir impuestos.
#
# 4. **Emergencias:**
#    - Mantener un **colchón de liquidez** (ej. 3-6 meses de gastos) en una cuenta de ahorro o depósito.
#
# 5. **Educación financiera:**
#    - Leer libros como *"El inversor inteligente"* (Benjamin Graham) o *"Pequeño libro para invertir con sentido común"* (John Bogle).
#    - Seguir fuentes como **Investopedia, Morningstar o el blog de Andrés Soto**.
#
# 6. **Alternativas si el riesgo es demasiado alto:**
#    - Reducir acciones tech al **5%** y aumentar bonos al **35%**.
#    - Usar un **fondo de perfil moderado** (ej. 50% acciones / 50% bonos) en lugar del 60/30/10.
#
# ---
#
# ## **CONCLUSIÓN FINAL**
# **Recomendación principal:**
# - **Asignar el 60% a un fondo mixto global (ej. Vanguard LifeStrategy 60%), 30% a bonos (ETF diversificado) y 10% a un ETF de acciones tech (ej. QQQ).**
# - **Mantener la disciplina de inversión a largo plazo**, evitando reaccionar a la volatilidad del mercado.
#
# **Beneficios de esta estrategia:**
# ✅ **Equilibrio entre crecimiento y seguridad.**
# ✅ **Diversificación automática** (no depende de elegir acciones individuales).
# ✅ **Bajo coste y gestión pasiva** (ideal para principiantes).
# ✅ **Flexibilidad** para ajustar riesgos en el futuro.
#
# **Riesgos a monitorizar:**
# ⚠ **Caída prolongada de los mercados** (ej. -20% en un año). Solución: Mantener la asignación y no vender en pánico.
# ⚠ **Inflación alta** (los bonos pueden perder valor real). Solución: Incluir un pequeño porcentaje en **REITs o materias primas** si la inflación persiste.
# ⚠ **Cambio en el perfil de riesgo** (ej. si el inversor se vuelve más conservador con el tiempo). Solución: Reajustar la cartera hacia más bonos.
#
# **Próximos pasos:**
# 1. **Abrir una cuenta en un bróker de bajo coste** (ej. MyInvestor, Indexa Capital, Interactive Brokers).
# 2. **Invertir los 10,000€ según la asignación propuesta.**
# 3. **Establecer aportaciones mensuales automáticas** (ej. 200€/mes) para aprovechar el interés compuesto.
# 4. **Revisar la cartera una vez al año** y reequilibrar si es necesario.
#
# ---
# **Resumen ejecutivo:**
# | **Aspecto**          | **Detalle**                                                                 |
# |----------------------|-----------------------------------------------------------------------------|
# | **Perfil**           | Moderado (capaz de asumir riesgo moderado-alto).                           |
# | **Asignación**       | 60% Fondo Mixto / 30% Bonos / 10% Acciones Tech.                            |
# | **Retorno esperado** | ~7% anual (base), con potencial de 9% en escenarios optimistas.           |
# | **Riesgo**           | Caídas máximas esperadas: ~15-20% en un año malo (aceptable para el perfil).|
# | **Recomendación**    | **Implementar la estrategia y mantenerla a largo plazo.**                   |
#
# Esta estrategia combina **crecimiento, diversificación y gestión pasiva**, ideal para un inversor de 25 años con tolerancia moderada al riesgo.
#
# === CALIDAD DEL ANÁLISIS ===
# ✓ Elementos clave: 7/7
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Limitaciones y Consideraciones de CoT
#
# ### ✅ Cuándo Usar CoT:
# - Problemas matemáticos complejos
# - Razonamiento lógico multi-paso
# - Análisis que requiere transparencia
# - Cuando necesitas verificar el proceso
# - Problemas donde el "por qué" es importante
#
# ### ⚠️ Limitaciones:
# - **Más tokens**: Respuestas más largas = mayor costo
# - **Tiempo**: Razonamiento paso a paso toma más tiempo
# - **Complejidad innecesaria**: Para problemas simples puede ser excesivo
# - **Razonamiento erróneo**: Puede mostrar lógica incorrecta convincente
#
# ### 🎯 Mejores Prácticas:
# 1. **Estructura clara**: Define pasos específicos
# 2. **Verificación**: Incluye auto-verificación cuando sea posible
# 3. **Ejemplos**: Usa few-shot para mostrar patrón deseado
# 4. **Temperatura baja**: Para razonamiento más consistente
# 5. **Validación externa**: Verifica respuestas críticas independientemente

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Chain-of-Thought** mejora dramáticamente la precisión en problemas complejos
# 2. **Zero-shot CoT** es tan simple como agregar "piensa paso a paso"
# 3. **Few-shot CoT** combina ejemplos con razonamiento para mejor control
# 4. **Estructura explícita** guía el razonamiento hacia análisis completos
# 5. **Auto-verificación** aumenta la confiabilidad de las respuestas
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Técnicas Avanzadas** como Tree of Thoughts (ToT), Self-Consistency, y otras metodologías cutting-edge que llevan el prompt engineering al siguiente nivel.
#
# ### Para Practicar:
# 1. Aplica CoT a problemas de tu dominio específico
# 2. Experimenta con diferentes niveles de estructura
# 3. Compara precisión con y sin CoT
# 4. Desarrolla patrones de verificación personalizados
